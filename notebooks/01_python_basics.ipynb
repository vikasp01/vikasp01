# %% [markdown]
# Notebook prepared by Mathieu Blondel.

# %% [markdown]
# # Welcome

# %% [markdown]
# Welcome to the first practical work of the week! In this practical, we will learn about the programming language Python as well as NumPy and Matplotlib, two fundamental tools for data science and machine learning in Python.

# %% [markdown]
# # Notebooks

# %% [markdown]
# This week, we will use Jupyter notebooks and Google colab as the primary way to practice machine learning. Notebooks are a great way to mix executable code with rich contents (HTML, images, equations written in LaTeX). Colab allows to run notebooks on the cloud for free without any prior installation, while leveraging the power of [GPUs](https://en.wikipedia.org/wiki/Graphics_processing_unit).

# %% [markdown]
# The document that you are reading is not a static web page, but an interactive environment called a notebook, that lets you write and execute code. Notebooks consist of so-called code cells, blocks of one or more Python instructions. For example, here is a code cell that stores the result of a computation (the number of seconds in a day) in a variable and prints its value:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Click on the "play" button to execute the cell. You should be able to see the result. Alternatively, you can also execute the cell by pressing Ctrl + Enter if you are on Windows / Linux or Command + Enter if you are on a Mac.

# %% [markdown]
# Variables that you defined in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Note that the order of execution is important. For instance, if we do not run the cell storing *seconds_in_a_day* beforehand, the above cell will raise an error, as it depends on this variable. To make sure that you run all the cells in the correct order, you can also click on "Runtime" in the top-level menu, then "Run all".

# %% [markdown]
# **Exercise.** Add a cell below this cell: click on this cell then click on "+ Code". In the new cell, compute the number of seconds in a year by reusing the variable *seconds_in_a_day*. Run the new cell.

# %% [markdown]
# # Python

# %% [markdown]
# Python is one of the most popular programming languages for machine learning, both in academia and in industry. As such, it is essential to learn this language for anyone interested in machine learning. In this section, we will review Python basics.

# %% [markdown]
# ## Arithmetic operations

# %% [markdown]
# Python supports the usual arithmetic operators: + (addition), * (multiplication), / (division), ** (power), // (integer division).

# %% [markdown]
# ## Lists

# %% [markdown]
# Lists are a container type for ordered sequences of elements. Lists can be initialized empty

# %%
my_list = []

# %% [markdown]
# or with some initial elements

# %%
my_list = [1, 2, 3]

# %% [markdown]
# Lists have a dynamic size and elements can be added (appended) to them

# %%
my_list.append(4)
my_list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# We can access individual elements of a list (indexing starts from 0)

# %%
my_list[2]
# Out:
# 3

# %% [markdown]
# We can access "slices" of a list using `my_list[i:j]` where `i` is the start of the slice (again, indexing starts from 0) and `j` the end of the slice. For instance:

# %%
my_list[1:3]
# Out:
# [2, 3]

# %% [markdown]
# Omitting the second index means that the slice shoud run until the end of the list

# %%
my_list[1:]
# Out:
# [2, 3, 4]

# %% [markdown]
# We can check if an element is in the list using `in`

# %%
5 in my_list
# Out:
# False

# %% [markdown]
# The length of a list can be obtained using the `len` function

# %%
len(my_list)
# Out:
# 4

# %% [markdown]
# ## Strings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %% [markdown]
# Strings are used to store text. They can delimited using either single quotes or double quotes

# %%
string1 = "some text"
string2 = 'some other text'

# %% [markdown]
# Strings behave similarly to lists. As such we can access individual elements in exactly the same way

# %%
string1[3]

# %% [markdown]
# and similarly for slices

# %%
string1[5:]

# %% [markdown]
# String concatenation is performed using the `+` operator

# %%
string1 + " " + string2

# %% [markdown]
# ## Conditionals

# %% [markdown]
# As their name indicates, conditionals are a way to execute code depending on whether a condition is True or False. As in other languages, Python supports `if` and `else` but `else if` is contracted into `elif`, as the example below demonstrates.

# %%
my_variable = 5
if my_variable < 0:
  print("negative")
elif my_variable == 0:
  print("null")
else: # my_variable > 0
  print("positive")

# %% [markdown]
# Here `<` and `>` are the strict `less` and `greater than` operators, while `==` is the equality operator (not to be confused with `=`, the variable assignment operator). The operators `<=` and `>=` can be used for less (resp. greater) than or equal comparisons.

# %% [markdown]
# Contrary to other languages, blocks of code are delimited using indentation. Here, we use 2-space indentation but many programmers also use 4-space indentation. Any one is fine as long as you are consistent throughout your code.

# %% [markdown]
# ## Loops

# %% [markdown]
# Loops are a way to execute a block of code multiple times. There are two main types of loops: while loops and for loops.

# %% [markdown]
# While loop

# %%
i = 0
while i < len(my_list):
  print(my_list[i])
  i += 1 # equivalent to i = i + 1

# %% [markdown]
# For loop

# %%
for i in range(len(my_list)):
  print(my_list[i])

# %% [markdown]
# If the goal is simply to iterate over a list, we can do so directly as follows

# %%
for element in my_list:
  print(element)

# %% [markdown]
# ## Functions

# %% [markdown]
# To improve code readability, it is common to separate the code into different blocks, responsible for performing precise actions: functions. A function takes some inputs and process them to return some outputs.

# %%
def square(x):
  return x ** 2

def multiply(a, b):
  return a * b

# Functions can be composed.
square(multiply(3, 2))

# %% [markdown]
# To improve code readability, it is sometimes useful to explicitly name the arguments

# %%
square(multiply(a=3, b=2))

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1.** Using a conditional, write the [relu](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)) function defined as follows
#
# $\text{relu}(x) = \left\{
#    \begin{array}{rl}
#      x, & \text{if }  x \ge 0 \\
#      0, & \text{otherwise }.
#    \end{array}\right.$

# %%
def relu(x):
  # Write your function here
  return

relu(-3)

# %% [markdown]
# **Exercise 2.** Using a foor loop, write a function that computes the [Euclidean norm](https://en.wikipedia.org/wiki/Norm_(mathematics)#Euclidean_norm) of a vector, represented as a list.

# %%
def euclidean_norm(vector):
  # Write your function here
  return

import numpy as np
my_vector = [0.5, -1.2, 3.3, 4.5]
# The result should be roughly 5.729746940310715
euclidean_norm(my_vector)

# %% [markdown]
# **Exercise 3.** Using a for loop and a conditional, write a function that returns the maximum value in a vector.

# %%
def vector_maximum(vector):
  # Write your function here
  return

# %% [markdown]
# **Bonus exercise.** if time permits, write a function that sorts a list in ascending order (from smaller to bigger) using the [bubble sort](https://en.wikipedia.org/wiki/Bubble_sort) algorithm.

# %%
def bubble_sort(my_list):
  # Write your function here
  return

my_list = [1, -3, 3, 2]
# Should return [-3, 1, 2, 3]
bubble_sort(my_list)

# %% [markdown]
# ## Going further

# %% [markdown]
# Clearly, it is impossible to cover all the language features in this short introduction. To go further, we recommend the following resources:

# %% [markdown]
# *   List of Python [tutorials](https://wiki.python.org/moin/BeginnersGuide/Programmers)
# * Four-hour [course](https://www.youtube.com/watch?v=rfscVS0vtbw) on Youtube

# %% [markdown]
# # NumPy

# %% [markdown]
# NumPy is a popular library for storing arrays of numbers and performing computations on them. Not only this enables to write often more succint code, this also makes the code faster, since most NumPy routines are implemented in C for speed.

# %% [markdown]
# To use NumPy in your program, you need to import it as follows

# %%
import numpy as np

# %% [markdown]
# # New Section

# %% [markdown]
# ## Array creation

# %% [markdown]
# NumPy arrays can be created from Python lists

# %%
my_array = np.array([1, 2, 3])
my_array

# %% [markdown]
# NumPy supports array of arbitrary dimension. For example, we can create two-dimensional arrays (e.g. to store a matrix) as follows

# %%
my_2d_array = np.array([[1, 2, 3], [4, 5, 6]])
my_2d_array

# %% [markdown]
# We can access individual elements of a 2d-array using two indices

# %%
my_2d_array[1, 2]

# %% [markdown]
# We can also access rows

# %%
my_2d_array[1]

# %% [markdown]
# and columns

# %%
my_2d_array[:, 2]

# %% [markdown]
# Arrays have a `shape` attribute

# %%
print(my_array.shape)
print(my_2d_array.shape)

# %% [markdown]
# Contrary to Python lists, NumPy arrays must have a type and all elements of the array must have the same type.

# %%
my_array.dtype

# %% [markdown]
# The main types are `int32` (32-bit integers), `int64` (64-bit integers), `float32` (32-bit real values) and `float64` (64-bit real values).

# %% [markdown]
# The `dtype` can be specified when creating the array

# %%
my_array = np.array([1, 2, 3], dtype=np.float64)
my_array.dtype

# %% [markdown]
# We can create arrays of all zeros using

# %%
zero_array = np.zeros((2, 3))
zero_array

# %% [markdown]
# and similarly for all ones using `ones` instead of `zeros`.

# %% [markdown]
# We can create a range of values using

# %%
np.arange(5)

# %% [markdown]
# or specifying the starting point

# %%
np.arange(3, 5)

# %% [markdown]
# Another useful routine is `linspace` for creating linearly spaced values in an interval. For instance, to create 10 values in `[0, 1]`, we can use

# %%
np.linspace(0, 1, 10)

# %% [markdown]
# Another important operation is `reshape`, for changing the shape of an array

# %%
my_array = np.array([1, 2, 3, 4, 5, 6])
my_array.reshape(3, 2)

# %% [markdown]
# Play with these operations and make sure you understand them well.

# %% [markdown]
# ## Basic operations

# %% [markdown]
# In NumPy, we express computations directly over arrays. This makes the code much more succint.

# %% [markdown]
# Arithmetic operations can be performed directly over arrays. For instance, assuming two arrays have a compatible shape, we can add them as follows

# %%
array_a = np.array([1, 2, 3])
array_b = np.array([4, 5, 6])
array_a + array_b

# %% [markdown]
# Compare this with the equivalent computation using a for loop

# %%
array_out = np.zeros_like(array_a)
for i in range(len(array_a)):
  array_out[i] = array_a[i] + array_b[i]
array_out

# %% [markdown]
# Not only this code is more verbose, it will also run much more slowly.

# %% [markdown]
# In NumPy, functions that operates on arrays in an element-wise fashion are called [universal functions](https://numpy.org/doc/stable/reference/ufuncs.html). For instance, this is the case of `np.sin`

# %%
np.sin(array_a)

# %% [markdown]
# Vector inner product can be performed using `np.dot`

# %%
np.dot(array_a, array_b)

# %% [markdown]
# When the two arguments to `np.dot` are both 2d arrays, `np.dot` becomes matrix multiplication

# %%
array_A = np.random.rand(5, 3)
array_B = np.random.randn(3, 4)
np.dot(array_A, array_B)

# %% [markdown]
# Matrix transpose can be done using `.transpose()` or `.T` for short

# %%
array_A.T

# %% [markdown]
# ## Slicing and masking

# %% [markdown]
# Like Python lists, NumPy arrays support slicing

# %%
np.arange(10)[5:]

# %% [markdown]
# We can also select only certain elements from the array

# %%
x = np.arange(10)
mask = x >= 5
x[mask]

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1.** Create a 3d array of shape (2, 2, 2), containing 8 values. Access individual elements and slices.

# %% [markdown]
# **Exercise 2.** Rewrite the relu function (see Python section) using [np.maximum](https://numpy.org/doc/stable/reference/generated/numpy.maximum.html). Check that it works on both a single value and on an array of values.

# %%
def relu_numpy(x):
  return

relu_numpy(np.array([1, -3, 2.5]))

# %% [markdown]
# **Exercise 3.** Rewrite the Euclidean norm of a vector (1d array) using NumPy (without for loop)

# %%
def euclidean_norm_numpy(x):
  return

my_vector = np.array([0.5, -1.2, 3.3, 4.5])
euclidean_norm_numpy(my_vector)

# %% [markdown]
# **Exercise 4.** Write a function that computes the Euclidean norms of a matrix (2d array) in a row-wise fashion. Hint: use the `axis` argument of [np.sum](https://numpy.org/doc/stable/reference/generated/numpy.sum.html).

# %%
def euclidean_norm_2d(X):
  return

my_matrix = np.array([[0.5, -1.2, 4.5],
                      [-3.2, 1.9, 2.7]])
# Should return an array of size 2.
euclidean_norm_2d(my_matrix)

# %% [markdown]
# **Exercise 5.** Compute the mean value of the features in the [iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html). Hint: use the `axis` argument on [np.mean](https://numpy.org/doc/stable/reference/generated/numpy.mean.html).

# %%
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)

# Result should be an array of size 4.

# %% [markdown]
# ## Going further

# %% [markdown]
# * NumPy [reference](https://numpy.org/doc/stable/reference/)
# * SciPy [lectures](https://scipy-lectures.org/)
# *   One-hour [tutorial](https://www.youtube.com/watch?v=QUT1VHiLmmI) on Youtube

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Basic plots

# %% [markdown]
# Matplotlib is a plotting library for Python.

# %% [markdown]
# We start with a rudimentary plotting example.

# %%
from matplotlib import pyplot as plt

x_values = np.linspace(-3, 3, 100)

plt.figure()
plt.plot(x_values, np.sin(x_values), label="Sinusoid")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Matplotlib example")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# We continue with a rudimentary scatter plot example. This example displays samples from the [iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html) using the first two features. Colors indicate class membership (there are 3 classes).

# %%
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)

X_class0 = X[y == 0]
X_class1 = X[y == 1]
X_class2 = X[y == 2]

plt.figure()
plt.scatter(X_class0[:, 0], X_class0[:, 1], label="Class 0", color="C0")
plt.scatter(X_class1[:, 0], X_class1[:, 1], label="Class 1", color="C1")
plt.scatter(X_class2[:, 0], X_class2[:, 1], label="Class 2", color="C2")
plt.show()

# %% [markdown]
# We see that samples belonging to class 0 can be linearly separated from the rest using only the first two features.

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1.** Plot the relu and the [softplus](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)#Softplus) functions on the same graph.

# %% [markdown]
# What is the main difference between the two functions?

# %% [markdown]
# **Exercise 2.** Repeat the same scatter plot but using the [digits dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html) instead.

# %%
from sklearn.datasets import load_digits
X, y = load_digits(return_X_y=True)

# %% [markdown]
# Are pixel values good features for classifying samples?

# %% [markdown]
# ## Going further
#
# *  Official [tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html)
# * [Tutorial](https://www.youtube.com/watch?v=qErBw-R2Ybk) on Youtube

# %%
# Install a library, for example, pandas
# !pip install pandas

# %% [markdown]
# To send emails using SMTP, you'll typically need:
# 1.  The SMTP server address and port of your email provider.
# 2.  Your email address and password (or an App Password for services like Gmail).
#
# **Note:** If you are using Gmail, you might need to enable "Less secure app access" in your Google Account settings (though this is less recommended now) or, preferably, set up an App Password. Using App Passwords is more secure.

# %%
import smtplib
from email.mime.text import MIMEText

# Email details
sender_email = "journeywithvikas0108@gmail.com"  # Replace with your email
sender_password = "qtaq xjyh nnsp unrt"  # Replace with your password or App Password
receiver_email = "vikasp01082000@gmail.com"  # Replace with recipient email
subject = "Test Email from Colab"
body = "This is a test email sent from Google Colab using Python's smtplib."

# Create the email message
msg = MIMEText(body)
msg['Subject'] = subject
msg['From'] = sender_email
msg['To'] = receiver_email

# Connect to the SMTP server and send the email
try:
    # For Gmail, the SMTP server is smtp.gmail.com and the port is 587 (for TLS) or 465 (for SSL)
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()  # Secure the connection
        server.login(sender_email, sender_password)
        server.sendmail(sender_email, receiver_email, msg.as_string())
    print("Email sent successfully!")
except Exception as e:
    print(f"Error sending email: {e}")

# %% [markdown]
# # Task
# Schedule the email communication code to run at a specific time or interval.

# %% [markdown]
# ## Install a scheduling library
#
# ### Subtask:
# Install a Python library for scheduling tasks, such as `schedule` or `apscheduler`.

# %% [markdown]
# **Reasoning**:
# The subtask is to install the `schedule` library. I will use `pip` to install the library in a new code cell.

# %%
# !pip install schedule

# %% [markdown]
# ## Modify the email sending code
#
# ### Subtask:
# Encapsulate the email sending logic within a function.

# %% [markdown]
# **Reasoning**:
# Encapsulate the existing email sending code within a function as instructed.

# %%
import smtplib
from email.mime.text import MIMEText

def send_scheduled_email():
    """Sends a scheduled email."""
    # Email details
    sender_email = "journeywithvikas0108@gmail.com"  # Replace with your email
    sender_password = "qtaq xjyh nnsp unrt"  # Replace with your password or App Password
    receiver_email = "vikasp01082000@gmail.com"  # Replace with recipient email
    subject = "Test Email from Colab"
    body = "This is a test email sent from Google Colab using Python's smtplib."

    # Create the email message
    msg = MIMEText(body)
    msg['Subject'] = subject
    msg['From'] = sender_email
    msg['To'] = receiver_email

    # Connect to the SMTP server and send the email
    try:
        # For Gmail, the SMTP server is smtp.gmail.com and the port is 587 (for TLS) or 465 (for SSL)
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()  # Secure the connection
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, receiver_email, msg.as_string())
        print("Email sent successfully!")
    except Exception as e:
        print(f"Error sending email: {e}")

# %% [markdown]
# ## Implement the scheduling
#
# ### Subtask:
# Use the installed scheduling library to schedule the function to run at a specific time or interval.

# %% [markdown]
# **Reasoning**:
# Import the necessary libraries for scheduling and time, then define and schedule the email sending function to run every minute, and finally, create a loop to continuously run pending scheduled jobs.

# %%
import schedule
import time
import smtplib
from email.mime.text import MIMEText

def send_scheduled_email():
    """Sends a scheduled email."""
    # Email details
    sender_email = "journeywithvikas0108@gmail.com"  # Replace with your email
    sender_password = "qtaq xjyh nnsp unrt"  # Replace with your password or App Password
    receiver_email = "vikasp01082000@gmail.com"  # Replace with recipient email
    subject = "Test Email from Colab"
    body = "This is a test email sent from Google Colab using Python's smtplib."

    # Create the email message
    msg = MIMEText(body)
    msg['Subject'] = subject
    msg['From'] = sender_email
    msg['To'] = receiver_email

    # Connect to the SMTP server and send the email
    try:
        # For Gmail, the SMTP server is smtp.gmail.com and the port is 587 (for TLS) or 465 (for SSL)
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()  # Secure the connection
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, receiver_email, msg.as_string())
        print("Email sent successfully!")
    except Exception as e:
        print(f"Error sending email: {e}")


# Schedule the email sending function to run every minute
schedule.every().minute.do(send_scheduled_email)

print("Scheduler started. Emails will be sent according to the schedule.")

# Loop indefinitely, checking for pending jobs and running them
while True:
    schedule.run_pending()
    time.sleep(1) # Wait 1 second before checking again

# %% [markdown]
# # Task
# Implement a scheduled email communication using SMTP and cron patterns with `apscheduler`.

# %% [markdown]
# ## Install apscheduler
#
# ### Subtask:
# Install the `apscheduler` library.

# %% [markdown]
# **Reasoning**:
# Install the `apscheduler` library using pip.

# %%
# !pip install apscheduler

# %% [markdown]
# ## Implement cron-based scheduling with apscheduler
#
# ### Subtask:
# Replace the `schedule` logic with `apscheduler`'s `CronTrigger` to schedule the email for a specific date and time using a cron-like pattern.

# %% [markdown]
# **Reasoning**:
# Import necessary components from `apscheduler`, instantiate the scheduler, add the email sending function as a job with a `CronTrigger` for scheduling, start the scheduler, and keep the script running with a `while` loop to allow the scheduler to operate in the background.

# %%
from apscheduler.schedulers.background import BackgroundScheduler
from apscheduler.triggers.cron import CronTrigger
import time
import smtplib
from email.mime.text import MIMEText

def send_scheduled_email_with_table():
    """Sends a scheduled email with an HTML table."""
    # Email details
    sender_email = "journeywithvikas0108@gmail.com"  # Replace with your email
    sender_password = "qtaq xjyh nnsp unrt"  # Replace with your password or App Password
    receiver_email = "vikasp01082000@gmail.com"  # Replace with recipient email
    subject = "Test Email with HTML Table from Colab"

    # Create an HTML table with styles
    html_body = """
    <html>
    <head>
      <style>
        table, th, td {
          border: 2px solid black; /* Bold black borders */
          border-collapse: collapse; /* Collapse borders to avoid double lines */
        }
        th {
          background-color: yellow; /* Yellow background for headers */
        }
      </style>
    </head>
    <body>
      <p>Hi there,</p>
      <p>This email contains a sample HTML table with styled headers and borders:</p>
      <table>
        <tr>
          <th>Header 1</th>
          <th>Header 2</th>
          <th>Header 3</th>
          <th>Header 4</th>
        </tr>
    """

    # Add 10 rows of data
    for i in range(10):
        html_body += f"""
        <tr>
          <td>Row {i+1} Col 1</td>
          <td>Row {i+1} Col 2</td>
          <td>Row {i+1} Col 3</td>
          <td>Row {i+1} Col 4</td>
        </tr>
        """

    html_body += """
      </table>
      <p>Best regards,</p>
      <p>Vikas Poojary</p>
    </body>
    </html>
    """

    # Create the email message with HTML content
    msg = MIMEText(html_body, 'html')
    msg['Subject'] = subject
    msg['From'] = sender_email
    msg['To'] = receiver_email

    # Connect to the SMTP server and send the email
    try:
        # For Gmail, the SMTP server is smtp.gmail.com and the port is 587 (for TLS) or 465 (for SSL)
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()  # Secure the connection
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, receiver_email, msg.as_string())
        print("Email with HTML table sent successfully!")
    except Exception as e:
        print(f"Error sending email with HTML table: {e}")


# Instantiate the BackgroundScheduler
scheduler = BackgroundScheduler()

# Add the email sending job with a CronTrigger
# This schedules the email to be sent at 8:20 AM UTC on the 7th day of every month.
# Change the function call to the new function that includes the table
scheduler.add_job(send_scheduled_email_with_table, CronTrigger(minute='15', hour='10', day='7', month='*', year='*'))

print("Scheduler started. Emails with HTML table will be sent according to the schedule.")

# Start the scheduler
scheduler.start()

# Keep the notebook alive
try:
    while True:
        time.sleep(2)  # Sleep to allow the scheduler to run in the background
except (KeyboardInterrupt, SystemExit):
    # Shut down the scheduler when the script is interrupted
    scheduler.shutdown()
# Out:
# Scheduler started. Emails with HTML table will be sent according to the schedule.
# Email with HTML table sent successfully!

# %% [markdown]
# # Task
# Integrate SQL and Pandas into the existing Python code to fetch data from a database, create an HTML table from the data using Pandas, and include the table in the scheduled email.

# %% [markdown]
# ## Install necessary libraries
#
# ### Subtask:
# Install libraries for database connectivity (e.g., `sqlalchemy` and a database driver like `psycopg2` for PostgreSQL, `mysql-connector-python` for MySQL, or `sqlite3` which is built-in for SQLite).

# %% [markdown]
# **Reasoning**:
# Install the necessary libraries for database connectivity, specifically `sqlalchemy` and `sqlite3` since `sqlite3` is a common built-in driver and doesn't require a separate pip install.

# %%
# !pip install sqlalchemy

# %% [markdown]
# ## Establish database connection
#
# ### Subtask:
# Write code to connect to your SQL database.

# %% [markdown]
# **Reasoning**:
# Import the `sqlite3` module and establish a connection to the database, creating a cursor object.

# %%
import sqlite3

# Define the path to your SQLite database file
database_path = 'my_database.db'

# Establish a connection to the database
conn = sqlite3.connect(database_path)

# Create a cursor object
cursor = conn.cursor()

print(f"Connected to the database: {database_path}")
# Out:
# Connected to the database: my_database.db

# %% [markdown]
# ## Fetch data using sql and load into pandas
#
# ### Subtask:
# Write a SQL query to retrieve the desired data and load it into a Pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import pandas, define a SQL query to create a sample table and insert data if it doesn't exist, then select the data into a pandas DataFrame and display the head.

# %%
import pandas as pd

# Define the SQL query to create a table if it doesn't exist
create_table_query = """
CREATE TABLE IF NOT EXISTS sample_data (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    value REAL
);
"""

# Define the SQL query to insert sample data
insert_data_query = """
INSERT INTO sample_data (name, value) VALUES
    ('Item A', 10.5),
    ('Item B', 25.3),
    ('Item C', 15.0),
    ('Item D', 30.2);
"""

# Define the SQL query to select data
select_data_query = "SELECT * FROM sample_data;"

# Execute the create table query
cursor.execute(create_table_query)
conn.commit() # Commit the changes

# Check if the table is empty and insert data if it is
cursor.execute("SELECT COUNT(*) FROM sample_data;")
count = cursor.fetchone()[0]
if count == 0:
    cursor.execute(insert_data_query)
    conn.commit() # Commit the changes after inserting data
    print("Sample data inserted.")
else:
    print("Sample data already exists.")


# Read data from the database into a pandas DataFrame
df = pd.read_sql_query(select_data_query, conn)

# Print the first few rows of the DataFrame
print("Data from database:")
display(df.head())
# Out:
# Sample data inserted.
# Data from database:
#    id    name  value
# 0   1  Item A   10.5
# 1   2  Item B   25.3
# 2   3  Item C   15.0
# 3   4  Item D   30.2

# %% [markdown]
# ## Generate html table from pandas dataframe
#
# ### Subtask:
# Modify the email sending function to create the HTML table directly from the Pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Modify the email sending function to accept a DataFrame and use its to_html() method to generate the HTML table.

# %%
from apscheduler.schedulers.background import BackgroundScheduler
from apscheduler.triggers.cron import CronTrigger
import time
import smtplib
from email.mime.text import MIMEText
import pandas as pd

def send_scheduled_email_with_table(dataframe):
    """Sends a scheduled email with an HTML table generated from a DataFrame."""
    # Email details
    sender_email = "journeywithvikas0108@gmail.com"  # Replace with your email
    sender_password = "qtaq xjyh nnsp unrt"  # Replace with your password or App Password
    receiver_email = "vikasp01082000@gmail.com"  # Replace with recipient email
    subject = "Test Email with HTML Table from Colab"

    # Convert DataFrame to HTML table
    html_table = dataframe.to_html(index=False) # index=False to exclude DataFrame index

    # Create the HTML body of the email
    html_body = f"""
    <html>
    <head>
      <style>
        table, th, td {{
          border: 2px solid black; /* Bold black borders */
          border-collapse: collapse; /* Collapse borders to avoid double lines */
        }}
        th {{
          background-color: yellow; /* Yellow background for headers */
        }}
      </style>
    </head>
    <body>
      <p>Hi there,</p>
      <p>Here is the data from the database:</p>
      {html_table}
      <p>Best regards,</p>
      <p>Vikas Poojary</p>
    </body>
    </html>
    """

    # Create the email message with HTML content
    msg = MIMEText(html_body, 'html')
    msg['Subject'] = subject
    msg['From'] = sender_email
    msg['To'] = receiver_email

    # Connect to the SMTP server and send the email
    try:
        # For Gmail, the SMTP server is smtp.gmail.com and the port is 587 (for TLS) or 465 (for SSL)
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()  # Secure the connection
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, receiver_email, msg.as_string())
        print("Email with HTML table sent successfully!")
    except Exception as e:
        print(f"Error sending email with HTML table: {e}")

# Instantiate the BackgroundScheduler
scheduler = BackgroundScheduler()

# Add the email sending job with a CronTrigger
# This schedules the email to be sent at 10:15 AM UTC on the 7th day of every month.
# Modify the trigger as needed for testing.
# Pass the DataFrame 'df' as an argument to the function
scheduler.add_job(send_scheduled_email_with_table, CronTrigger(minute='15', hour='10', day='7', month='*', year='*'), args=[df])

print("Scheduler started. Emails with HTML table will be sent according to the schedule.")

# Start the scheduler
scheduler.start()

# Keep the notebook alive
try:
    while True:
        time.sleep(2)  # Sleep to allow the scheduler to run in the background
except (KeyboardInterrupt, SystemExit):
    # Shut down the scheduler when the script is interrupted
    scheduler.shutdown()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-847064946.py in <cell line: 0>()
# ----> 1 from apscheduler.schedulers.background import BackgroundScheduler
#       2 from apscheduler.triggers.cron import CronTrigger
#       3 import time
#       4 import smtplib
#       5 from email.mime.text import MIMEText
#
# ModuleNotFoundError: No module named 'apscheduler'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Reasoning**:
# The previous command failed because the `apscheduler` library was not found. Although a previous cell indicated it was installed, the kernel might have reset or the installation was not successful in the execution environment where the current cell is run. I will reinstall `apscheduler` to ensure it's available.

# %%
# !pip install apscheduler
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 1.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Reasoning**:
# Now that `apscheduler` is confirmed to be installed, I will re-run the code from the previous failed attempt to modify the email sending function to accept a DataFrame and use its to_html() method, and set up the scheduler to use this function with the existing `df` DataFrame.

# %%
from apscheduler.schedulers.background import BackgroundScheduler
from apscheduler.triggers.cron import CronTrigger
import time
import smtplib
from email.mime.text import MIMEText
import pandas as pd

def send_scheduled_email_with_table(dataframe):
    """Sends a scheduled email with an HTML table generated from a DataFrame."""
    # Email details
    sender_email = "journeywithvikas0108@gmail.com"  # Replace with your email
    sender_password = "qtaq xjyh nnsp unrt"  # Replace with your password or App Password
    receiver_email = "vikasp01082000@gmail.com"  # Replace with recipient email
    subject = "Test Email with HTML Table from Colab"

    # Convert DataFrame to HTML table
    html_table = dataframe.to_html(index=False) # index=False to exclude DataFrame index

    # Create the HTML body of the email
    html_body = f"""
    <html>
    <head>
      <style>
        table, th, td {{
          border: 2px solid black; /* Bold black borders */
          border-collapse: collapse; /* Collapse borders to avoid double lines */
        }}
        th {{
          background-color: yellow; /* Yellow background for headers */
        }}
      </style>
    </head>
    <body>
      <p>Hi there,</p>
      <p>Here is the data from the database:</p>
      {html_table}
      <p>Best regards,</p>
      <p>Vikas Poojary</p>
    </body>
    </html>
    """

    # Create the email message with HTML content
    msg = MIMEText(html_body, 'html')
    msg['Subject'] = subject
    msg['From'] = sender_email
    msg['To'] = receiver_email

    # Connect to the SMTP server and send the email
    try:
        # For Gmail, the SMTP server is smtp.gmail.com and the port is 587 (for TLS) or 465 (for SSL)
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()  # Secure the connection
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, receiver_email, msg.as_string())
        print("Email with HTML table sent successfully!")
    except Exception as e:
        print(f"Error sending email with HTML table: {e}")


# Instantiate the BackgroundScheduler
scheduler = BackgroundScheduler()

# Add the email sending job with a CronTrigger
# This schedules the email to be sent at 10:15 AM UTC on the 7th day of every month.
# Modify the trigger as needed for testing.
# Pass the DataFrame 'df' as an argument to the function
scheduler.add_job(send_scheduled_email_with_table, CronTrigger(minute='15', hour='10', day='7', month='*', year='*'), args=[df])

print("Scheduler started. Emails with HTML table will be sent according to the schedule.")

# Start the scheduler
scheduler.start()

# Keep the notebook alive
try:
    while True:
        time.sleep(2)  # Sleep to allow the scheduler to run in the background
except (KeyboardInterrupt, SystemExit):
    # Shut down the scheduler when the script is interrupted
    scheduler.shutdown()
# Out:
# Scheduler started. Emails with HTML table will be sent according to the schedule.
